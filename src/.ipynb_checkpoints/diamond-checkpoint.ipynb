# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import missingno as msno
import pandas_profiling
from diamond_util import filter_iqr, eda_category_distr, eda_missing_value, label_cat_encode
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import Lasso, LinearRegression, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
#from sklearn.externals import joblib
import joblib
import pickle

import sqlalchemy as db
from sqlalchemy import create_engine, ForeignKey
from sqlalchemy import Column, Date, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, backref
from sqlalchemy.orm import sessionmaker
import os

# %matplotlib inline
# Customise plots
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 12

# Load MYSql connector 
SQL_USR, SQL_PSW= os.environ['SQL_USR'], os.environ['SQL_PSW']
mysql_str = 'mysql+mysqlconnector://'+SQL_USR+':'+SQL_PSW+'@localhost:3306/'
engine = db.create_engine(mysql_str+'Diamonds')

# Load database diamonds
con=engine.connect()
df_size=con.execute('SELECT COUNT(*) FROM physical;').fetchall()[0][0]
print('Dataframe size: {}'.format(df_size))

# Load data
df = pd.read_sql('SELECT * FROM physical;', engine).drop('id', axis=1)

# Select category(number columns)
cat_columns = df.select_dtypes(exclude=np.number).columns.tolist()
num_columns = df.select_dtypes(include=np.number).columns.tolist()


# cut category
cut_dtype = pd.api.types.CategoricalDtype(categories=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], ordered=True)
df['cut'] = df['cut'].astype(cut_dtype)

df['cut'].describe()
# color category
color_dtype = pd.api.types.CategoricalDtype(categories=['D', 'E', 'F', 'G', 'H', 'I', 'J'], ordered=True)
df['color'] = df['color'].astype(color_dtype)
# clarity category

color_dtype = pd.api.types.CategoricalDtype(categories=['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'][::-1], ordered=True)
df['clarity'] = df['clarity'].astype(color_dtype)
df.head()
# Out:
# Dataframe size: 53940
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  334.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75

# %% [markdown]
# ## Create profiling report

# %%
#pandas profiling
profile = df.profile_report(title='Diamond Profiling Report')
profile.to_file(output_file="../report/diamond_profiling.html")

# %% [markdown]
# ## Missing values

# %%
msno.matrix(df)
eda_missing_value(df)
# Out:
# Missing values:
# ---------------
# carat: 0 (0.0 %)
# cut: 0 (0.0 %)
# color: 0 (0.0 %)
# clarity: 0 (0.0 %)
# depth: 0 (0.0 %)
# table: 0 (0.0 %)
# price: 0 (0.0 %)
# x: 0 (0.0 %)
# y: 0 (0.0 %)
# z: 0 (0.0 %)

# %% [markdown]
# ## Distribution of numerical data

# %%
colors = sns.color_palette("deep")
fig,axes = plt.subplots(7,2, figsize = (12,16)) 
for idx, col in enumerate(num_columns):
    sns.distplot(df[col], color = colors[0], ax = axes[idx,0])
    sns.boxplot(y= df[col], color = colors[0], ax = axes[idx,1])
plt.suptitle("Distribution of Quantitative Data (boxplots)", size = 16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ## Category features

# %%
# Category features
fig, axes = plt.subplots(1,3, figsize = (12,5))
i = 0
for var_name in cat_columns:
    df[var_name].value_counts().sort_values().plot(kind = 'barh', color = 'C0', ax = axes[i])
    axes[i].set_title(var_name)
    i += 1
plt.tight_layout()
plt.show()

# %%
# Explore category variable distribution
# TODO: define a engineered variable price/carat and groupby category as function of this.

clar_order = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
cut_order = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_order = sorted(df['color'].unique().tolist(), reverse = True)
fig, axes = plt.subplots(1,3, figsize = (12,5))
sns.boxplot(x = "cut", y = "price", data = df, order = cut_order, ax = axes[0], palette = 'Blues')
sns.boxplot(x = 'clarity', y = 'price', data = df, order = clar_order, ax = axes[1], palette = 'Blues')
sns.boxplot(x = 'color', y = 'price', data = df, order = color_order, ax = axes[2], palette = 'Blues')
plt.suptitle("Diamond Price by Cut and Clarity", size = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data cleaning

# %%
# size
col_size = ['x', 'y', 'z']
fig, ax = plt.subplots(nrows=len(col_size), ncols=1)
for idx, col in enumerate(col_size):
    sns.boxplot(col, data=df, ax=ax[idx])
    ax[idx].set_title('size' +col)
    plt.tight_layout()
plt.show()
# check zero size and cleaning
print('Zero size data count:')
print('---------------------')
for col in col_size:
    cnd_zero = df[col] < 1e-5
    zero_size_data = df.loc[cnd_zero, col].count()
    print('{0}: {1} ({2}%)'.format(col, zero_size_data, zero_size_data/df.shape[0]))

print('\nZero size data cleaning:')
print('---------------------')
for col in col_size:
    # cleaning: remove zero size data
    cnd_zero = df[col] < 1e-5
    df = df[~cnd_zero].copy()
print('done.')

print('\nOutliers in y, z count:')
print('---------------------')
for col in ['y', 'z']:
    cnd_outlier = df[col] >20
    outliers_data = df.loc[cnd_outlier, col].count()
    print('{0}: {1} ({2}%)'.format(col, outliers_data, outliers_data/df.shape[0]))

print('\nOutliers in y, z cleaning')
print('---------------------')
for col in ['y', 'z']:
    # cleaning: remove zero size data
    cnd_outlier = df[col] >20
    df = df[~cnd_outlier].copy()
print('done.')
# Out:
# Zero size data count:
# ---------------------
# x: 8 (0.00014831294030404152%)
# y: 7 (0.00012977382276603634%)
# z: 20 (0.0003707823507601038%)
#
# Zero size data cleaning:
# ---------------------
# done.
#
# Outliers in y, z count:
# ---------------------
# y: 2 (3.70919881305638e-05%)
# z: 1 (1.85459940652819e-05%)
#
# Outliers in y, z cleaning
# ---------------------
# done.

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53917.000000  53917.000000  53917.000000  53917.000000  53917.000000
# mean       0.797687     61.749565     57.456939   3930.910474      5.731605
# std        0.473777      1.432318      2.234069   3987.215003      1.119402
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53917.000000  53917.000000
# mean       5.733428      3.539409
# std        1.111272      0.691620
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ## Encoding category features

# %%
# Encoding category features (ordinal)
df_enc = df.copy()

for cat in cat_columns:
    df_enc=label_cat_encode(df_enc, cat).copy()
    df_enc[cat] = df_enc[cat].astype(int)
df_enc
# Out:
#        carat  cut  color  clarity  depth  table   price     x     y     z
# 0       0.23    0      0        0   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    1      0        1   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23    2      0        2   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    1      1        3   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31    2      2        0   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72    0      6        1   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72    2      6        1   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70    3      6        1   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    1      3        0   61.0   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75    0      6        0   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53917 rows x 10 columns]

# %%
# Correlation matrix after labelencoding
print(df_enc.corr()['price'].sort_values(ascending=False))

plt.figure(figsize=(6, 5))
sns.heatmap(df_enc.corr(), cmap = "RdBu_r", square = True, annot=True, cbar=True)
plt.title("Correlation Between Variables")
plt.tight_layout()
plt.show()
# Out:
# price      1.000000
# carat      0.921586
# y          0.888818
# x          0.887221
# z          0.882107
# table      0.127241
# cut        0.049522
# depth     -0.010653
# color     -0.016700
# clarity   -0.140211
# Name: price, dtype: float64

# %% [markdown]
# ## Model analysis: KFold

# %%
# Results of several ML models with standard parameters

X = df_enc.drop('price', axis=1).values
y = df_enc['price'].values

def model_kfold(X, y, model):
    X = df_enc.drop('price', axis=1).values
    y = df_enc['price'].values

    kf=KFold(n_splits=5, random_state=123456, shuffle=True)
    rmse_train, r2_train, rmse_test, r2_test = [], [], [], []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train, y_train)
        y_pred_test = model.predict(X_test)
        y_pred_train = model.predict(X_train)

        rmse_train.append(np.sqrt(mean_squared_error(y_train, y_pred_train)))
        r2_train.append(r2_score(y_train, y_pred_train))
        
        rmse_test.append(np.sqrt(mean_squared_error(y_test, y_pred_test)))
        r2_test.append(r2_score(y_test, y_pred_test))
    
    avg_r2_train_score = np.mean(r2_train)
    avg_r2_test_score = np.mean(r2_test)
    
    print('rmse avg train: {}'.format(np.mean(rmse_train)))
    print('r2 avg train: {}'.format(np.mean(r2_train)))

    print('rmse avg test: {}'.format(np.mean(rmse_test)))
    print('r2 avg test: {}'.format(np.mean(r2_test)))
    
    return avg_r2_train_score, avg_r2_test_score

lr_pipeline = Pipeline([
    ('std', StandardScaler()),\
    ('lr', LinearRegression())
])

rd_pipeline = Pipeline([
    ('std', StandardScaler()),\
    ('lr', Ridge(alpha=10))
])

ls_pipeline = Pipeline([
    ('std', StandardScaler()),\
    ('lr', Lasso(alpha=10))
])

rfr_pipeline = Pipeline([
#    ('std', StandardScaler()),\
    ('rfr', RandomForestRegressor(n_estimators=10,\
                                  max_depth=6))
])

gbr_pipeline =Pipeline([
    ('std', StandardScaler()),\
    ('gbr', GradientBoostingRegressor())
])

models={
        'linear_regression' : lr_pipeline,\
        'Ridge': rd_pipeline,\
        'Lasso': ls_pipeline,\
        'Random_forest_regression' : rfr_pipeline,\
        'Gradient_boosted_regression' : gbr_pipeline
       }

results={}
for key, md in models.items():
    print(key)
    print('------------')
    results[key] = model_kfold(X, y, md)
    print('\n\n')
# Out:
# linear_regression
# ------------
# rmse avg train: 1407.618004377732
# r2 avg train: 0.8753552552725257
# rmse avg test: 1413.3645244335084
# r2 avg test: 0.8741678069005024
#
#
#
# Ridge
# ------------
# rmse avg train: 1407.960505655963
# r2 avg train: 0.875294605251242
# rmse avg test: 1411.3638437191594
# r2 avg test: 0.8745315079968534
#
#
#
# Lasso
# ------------
# rmse avg train: 1421.196967237623
# r2 avg train: 0.8729385421386514
# rmse avg test: 1421.6674401033586
# r2 avg test: 0.8727147595555598
#
#
#
# Random_forest_regression
# ------------
# rmse avg train: 903.5018556954012
# r2 avg train: 0.9486468738595486
# rmse avg test: 922.1362875373258
# r2 avg test: 0.9464817272186131
#
#
#
# Gradient_boosted_regression
# ------------
# rmse avg train: 716.7175076728334
# r2 avg train: 0.9676863697150185
# rmse avg test: 736.0758400486008
# r2 avg test: 0.9659069551729921

# %%
print('Models Comparison')
print('--------------------')
df_kfold_comparison = pd.DataFrame.from_dict(results).transpose()
df_kfold_comparison.columns = ['avg_r2_train_score', 'avg_r2_test_score']
df_kfold_comparison = df_kfold_comparison.sort_values('avg_r2_test_score', ascending=False)

df_kfold_comparison.to_excel('../report/models_comparison.xlsx', engine='xlsxwriter')
print('Done.')
df_kfold_comparison
# Out:
# Models Comparison
# --------------------
# Done.
#                              avg_r2_train_score  avg_r2_test_score
# Gradient_boosted_regression            0.967686           0.965907
# Random_forest_regression               0.948647           0.946482
# Ridge                                  0.875295           0.874532
# linear_regression                      0.875355           0.874168
# Lasso                                  0.872939           0.872715

# %%
# Feature importance analysis with randomforest
X = df_enc.drop('price', axis=1).values
y = df_enc['price'].values

X_train, X_test, y_train, y_test = train_test_split(X, y,\
                                                   test_size=0.25,\
                                                   random_state=654321)
rfr = RandomForestRegressor(n_estimators=10,\
                                  max_depth=4)

rfr.fit(X_train, y_train)

print('Feature importance analysis:')
print('----------------------------')
importances = rfr.feature_importances_
sorted_index = np.argsort(importances)
labels = df_enc.drop(columns=['price']).columns[sorted_index]

# Customise plots
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 20

plt.figure(figsize=(10, 10))
plt.barh(range(X.shape[1]), importances[sorted_index], tick_label=labels)
plt.title('Feature importance')
#plt.xlabel('Importance', fontsize=18)
#plt.ylabel('Features', fontsize=18)
plt.tight_layout()
#plt.savefig('../images/rf_feature_importance.png', dpi=300)
plt.show()
# Out:
# Feature importance analysis:
# ----------------------------

# %%
# Save models
print('Saving models')
print('-------------')
for key, md in models.items():
    X = df_enc.drop('price', axis=1).values
    y = df_enc['price'].values
    
    X_train, X_test, y_train, y_test = train_test_split(X, y,\
                                                        test_size=0.25,\
                                                        random_state=654321)
    # Fit the model on training set
    mdl = models[key]
    mdl.fit(X_train, y_train)

    filename = '../models/model_'+key+'.pkl'
    joblib.dump(mdl, filename)
print('Done.')
    
#x0 = {
#    'carat': [0.23],\
#    'cut': ['Ideal'],\
#    'color': ['E'],\
#    'clarity': ['SI2'],\
#    'depth': [61.5],\
#    'table': [55.0],\
#    'price': [326],\
#    'x': [3.95],\
#    'y': [3.98],\
#    'z': [2.43]
#}
#x0= pd.DataFrame.from_dict(x0)

x0 = df.sample(n=1000, random_state=12345).copy()
#x0 = df.copy()

def preprocessing_pred(x0, model_filename):
    """
    Price prediction model.
    
    Params
    ------
    x0: ps.DataFrame
        dataset to be predicted
    model_filename: string
        filename of saved model
        
    Returns
    -------
    pd.DataFrame:
        results dataframe
    """
    #load the model from disk
    mdl = joblib.load(open(filename, 'rb'))
    
    x = x0.drop('price', axis=1)
    
    for cat in cat_columns:
        x=label_cat_encode(x, cat).copy()
        x[cat] = x[cat].astype(int)
    x = x.values
    
    y_true = x0['price'].values
    y_pred = mdl.predict(x)
    err_perc = np.round(np.abs((y_true-y_pred)/y_true * 100), 2)
    df_pred = pd.DataFrame([*zip(y_true, y_pred, err_perc)], columns=['price_true', 'price_pred', 'err (%)'])
    return df_pred
    
df_pred = preprocessing_pred(x0, '../models/model_Gradient_boosted_regression.pkl')
#df_pred = preprocessing_pred(x0, '../models/model_Random_forest_regression.pkl')

print(df_pred['err (%)'].mean())
dat = df_pred[df_pred['err (%)']<30]
plt.figure()
sns.lineplot(dat['price_true'], dat['price_true'], lw=3, color='black')
sns.scatterplot(dat['price_true'], dat['price_pred'])
plt.show()

#plt.figure()
#sns.lineplot(df_pred['price_true'], df_pred['price_true'], lw=3, color='black')
#sns.scatterplot(df_pred['price_true'], df_pred['price_pred'])
#plt.show()
# Out:
# Saving models
# -------------
# Done.
# 41.69138999999999

# %%
def preprocessing_dat_pred(x0, model_filename):
    """
    Price prediction model.
    
    Params
    ------
    x0: ps.DataFrame
        dataset to be predicted
    model_filename: string
        filename of saved model
        
    Returns
    -------
    pd.DataFrame:
        results dataframe
    """
    #load the model from disk
    mdl = joblib.load(open(filename, 'rb'))
    
    x = x0.drop('price', axis=1)
    
    for cat in cat_columns:
        x=label_cat_encode(x, cat).copy()
        x[cat] = x[cat].astype(int)
    x = x.values
    
    y_true = x0['price'].values
    y_pred = mdl.predict(x)
    err_perc = np.round(np.abs((y_true-y_pred)/y_true * 100), 2)
    #df_pred = pd.DataFrame([*zip(y_true, y_pred, err_perc)], columns=['price_true', 'price_pred', 'err (%)'])
    df_pred = x0.copy()
    y0_pred = pd.DataFrame(y_pred, columns=['price_pred'])
    
    df_pred = pd.concat([df_pred, y0_pred], axis=1).copy()
    
    return df_pred

dat = preprocessing_dat_pred(df, '../models/model_Gradient_boosted_regression.pkl')
dat_clarity=dat.groupby('clarity')['price', 'price_pred'].mean()
dat_color = dat.groupby('color')['price', 'price_pred'].mean()


# Customise plots
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 12

plt.figure()
sns.scatterplot(x='price', y='price_pred', hue=dat_clarity.index, data=dat_clarity)
plt.plot(dat_clarity['price'], dat_clarity['price'], c='black')
plt.xlabel('Price')
plt.ylabel('Price Predicted')
plt.savefig('../images/gbr_mean_clarity_prediction.png', dpi=300)
plt.tight_layout()
plt.show()

plt.figure()
sns.scatterplot(x='price', y='price_pred', hue=dat_color.index, data=dat_color)
plt.plot(dat_color['price'], dat_color['price'], c='black')
plt.xlabel('Price')
plt.ylabel('Price Predicted')
plt.savefig('../images/gbr_mean_color_prediction.png', dpi=300)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

cv = ShuffleSplit(n_splits=50, test_size=0.2, random_state=0)
fig_to_sav = plot_learning_curve(GradientBoostingRegressor(), '', X, y, ylim=(0.9, 1.01), cv=cv, n_jobs=4)


plt.figure()
#plt.tight_layout()
fig_to_sav.savefig('../images/gbr_learning_curve.png', dpi=300)
fig_to_sav.show()
